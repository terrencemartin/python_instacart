# %% [markdown]
# ## import

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
path=r'C:\Users\t3mar\Career Foundry\Data Analytics\Project 4 Instacart'

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Orders & Products.pkl'))

# %%
df = ords_prods_merged[:1000000]

# %% [markdown]
# ## if else

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_44480\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## .loc

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## busy

# %%
ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merged['busiest_day'] = result

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
# 2.
ords_prods_merged.loc[ords_prods_merged['order_dow'] < 2, 'dow_loc'] = 'Busiest Days'

# %%
ords_prods_merged.loc[(ords_prods_merged['order_dow'] > 2) & (ords_prods_merged['order_dow'] < 5), 'dow_loc'] = 'Slowest Days'

# %%
# 3.
ords_prods_merged['dow_loc'].value_counts(dropna = False)
# Out:
# NaN             12916111
# Busiest Days    11864412
# Slowest Days     7624336
# Name: dow_loc, dtype: int64

# %% [markdown]
# #### the increase in group sizes for busiest and slowest makes sense.

# %%
# 4.
ords_prods_merged.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'Unnamed: 0', 'product_name',
#        'aisle_id', 'department_id', 'prices', '_merge', 'price_range_loc',
#        'busiest_day', 'dow_loc'],
#       dtype='object')

# %%
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# calculate average
hour_vc = ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
hour_vc.mean()
# Out:
# 1350202.4583333333

# %%
def hour_label(row):

  if row['order_hour_of_day'] <= 6:
    return 'Fewest orders'
  elif (row['order_hour_of_day'] > 8) and (row['prices'] <= 17):
    return 'Most orders'
  else: return 'Average orders'

# %%
df['busy_hours'] = df.apply(hour_label, axis=1)
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_14436\3039055659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['busy_hours'] = df.apply(hour_label, axis=1)

# %%
df['busy_hours'].value_counts()
# Out:
# Most orders       887479
# Average orders     86953
# Fewest orders      25568
# Name: busy_hours, dtype: int64

# %%
# 5.
busy_period_of_day = df['busy_hours']

# %%
busy_period_of_day.value_counts()
# Out:
# Most orders       887479
# Average orders     86953
# Fewest orders      25568
# Name: busy_hours, dtype: int64

# %%
df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Busy hours 1000000.pkl'))
