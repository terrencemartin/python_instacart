# %% [markdown]
# # Import

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# set path
path=r'C:\Users\t3mar\Career Foundry\Data Analytics\Project 4 Instacart\02 Data'

# %%
# import data
df_cst = pd.read_csv(os.path.join(path, 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# # Evaluate

# %%
# rename columns
df_cst.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
df_cst
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
df_cst.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
df_cst.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
df_cst.rename(columns = {'n_dependants' : 'Dependants'}, inplace = True)

# %%
df_cst.rename(columns = {'fam_status' : 'Relationship'}, inplace = True)

# %%
df_cst
# Out:
#         user_id First Name Last Name  Gender           State  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
# data types
df_cst.dtypes
# Out:
# user_id          int64
# First Name      object
# Last Name       object
# Gender          object
# State           object
# Age              int64
# date_joined     object
# Dependants       int64
# Relationship    object
# income           int64
# dtype: object

# %%
# nulls
df_cst.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Last Name           0
# Gender              0
# State               0
# Age                 0
# date_joined         0
# Dependants          0
# Relationship        0
# income              0
# dtype: int64

# %%
# duplicates
df_cst_2 = df_cst.drop_duplicates()

# %%
df_cst_2.tail()
# Out:
#         user_id First Name Last Name  Gender           State  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         Dependants Relationship  income
# 206204           1      married  148828
# 206205           3      married  168639
# 206206           2      married   53374
# 206207           1      married   99799
# 206208           1      married   57095

# %% [markdown]
# # Merge

# %%
# import
ord_prd_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'OrdPrdMerge3.pkl'))

# %%
# merge
cst_ord_prd = ord_prd_merge.merge(df_cst, on = 'user_id', indicator = False)

# %%
cst_ord_prd[:10]
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  weekday  order_hour_of_day  \
# 0             0   2539329        1             1        2                  8
# 1             1   2398795        1             2        3                  7
# 2             2    473747        1             3        3                 12
# 3             3   2254736        1             4        4                  7
# 4             4    431534        1             5        4                 15
# 5             5   3367565        1             6        2                  7
# 6             6    550135        1             7        1                  9
# 7             7   3108588        1             8        1                 14
# 8             8   2295261        1             9        1                 16
# 9             9   2550362        1            10        4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# ...

# %%
cst_ord_prd.to_pickle(os.path.join(path, 'Prepared Data', 'CstOrdPrd1.pkl'))
