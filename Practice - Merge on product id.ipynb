# %% [markdown]
# # Import

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
path=r'C:\Users\t3mar\Career Foundry\Data Analytics\Project 4 Instacart\02 Data'

# %%
# import clean products
df_prd_2 = pd.read_csv(os.path.join(path, 'Prepared Data', 'Products WRNGLD.csv'), index_col = False)

# %%
# import mergeable orders
df_ord_prd = pd.read_pickle(os.path.join(path, 'Prepared Data', 'OrdPrdMerged.pkl'))

# %% [markdown]
# # Merge

# %%
# drop column
df_ord_prd_2 = df_ord_prd.drop(columns = ['_merge'])

# %%
df_merged = df_ord_prd_2.merge(df_prd_2, on = 'product_id', indicator = True)

# %%
df_merged
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  weekday  \
# 0                    0   2539329        1             1        2
# 1                    1   2398795        1             2        3
# 2                    2    473747        1             3        3
# 3                    3   2254736        1             4        4
# 4                    4    431534        1             5        4
# ...                ...       ...      ...           ...      ...
# 32404854       3360493   1320836   202557            17        2
# 32404855       3360494     31526   202557            18        5
# 32404856       3376038    758936   203436             1        2
# 32404857       3376039   2745165   203436             2        3
# 32404858       3408036   3093936   205420             1        4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path,'Prepared Data', 'OrdPrdMerge2.pkl'))
